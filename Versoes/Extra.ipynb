# %%
import pandas as pd

# %%
dados_socio = pd.read_csv("dados-socio-economicos-20171", sep=';')
dados_socio.dropna()
# Out:
#                             id_discente   ano  periodo      renda  \
# 0      9098c14ef1ad865247b2abda52806775  2017        1     2000.0
# 1      694c169b65f2043aa95138e0037c8908  2017        1     3000.0
# 2      bdd599acd452057916e6b4f177baf6a9  2017        1     1000.0
# 3      430241bbd7a5248f09e6994995a33f3b  2017        1     3200.0
# 4      cf43986a0745aa181201a9df000d5368  2017        1     4600.0
# 5      e6c6a2cf710c27fe7c723c6fc8637624  2017        1     4500.0
# 6      c80db7072a2416442aff28c2b6bce61f  2017        1     1448.0
# 7      7210dc39996acda1c74a7d7343b6715b  2017        1     3098.0
# 8      2abcedcdc34c4f16b7514673db67221f  2017        1     1240.0
# 9      4c7b1574824787ab23c84062a1814ea5  2017        1      900.0
# 10     375380f65c8a6a91972fd11a044cb0a9  2017        1      937.0
# 11     5e7b890f9d1e141f34784928f1ca5735  2017        1     2848.0
# 12     9b0cf322d76f570faab426f9eadad163  2017        1     2811.0
# ...

# %%
dados_socio.pivot_table( index = 'escola_ens_medio', values='id_discente', aggfunc='count')
# Out:
#                                                     renda
# escola_ens_medio
# Em escola Particular, com bolsa                       783
# Outro tipo de escola                                  145
# Parte em escola pública parte em escola particu...    633
# Todo em escola particular                            3457
# Todo em escola publica                               8880

# %%
dados_socio.pivot_table( index = 'renda', values='id_discente', aggfunc='count')
# Out:
#               id_discente
# renda
# 0.000000e+00           86
# 1.000000e+00           35
# 2.000000e+00           30
# 2.811000e+00            1
# 3.000000e+00            9
# 4.000000e+00           10
# 5.000000e+00            5
# 6.000000e+00            1
# 7.000000e+00            2
# 8.000000e+00            1
# 9.000000e+00            1
# 1.200000e+01            1
# 1.500000e+01            3
# 2.000000e+01            1
# 3.000000e+01            1
# 3.500000e+01            1
# 3.700000e+01            1
# 7.700000e+01            3
# 8.000000e+01            1
# 8.200000e+01            2
# 8.500000e+01            5
# 8.700000e+01            2
# 1.000000e+02            4
# 1.070000e+02            2
# 1.080000e+02            2
# 1.120000e+02            2
# 1.240000e+02            5
# 1.270000e+02            1
# 1.300000e+02            1
# 1.310000e+02            1
# ...                   ...
# 6.035640e+05            1
# 6.500000e+05            1
# 6.600000e+05            1
# ...
